# %%
# Libraries 
import pandas as pd
import numpy as np

# %%
# Read the excel file 
data = pd.read_csv('dataset.csv')
data.head()
# Out:
#    Id       EmployeeName                                        JobTitle  \
# 0   1     NATHANIEL FORD  GENERAL MANAGER-METROPOLITAN TRANSIT AUTHORITY
# 1   2       GARY JIMENEZ                 CAPTAIN III (POLICE DEPARTMENT)
# 2   3     ALBERT PARDINI                 CAPTAIN III (POLICE DEPARTMENT)
# 3   4  CHRISTOPHER CHONG            WIRE ROPE CABLE MAINTENANCE MECHANIC
# 4   5    PATRICK GARDNER    DEPUTY CHIEF OF DEPARTMENT,(FIRE DEPARTMENT)
#
#      BasePay  OvertimePay   OtherPay  Benefits   TotalPay  TotalPayBenefits  \
# 0  167411.18         0.00  400184.25       NaN  567595.43         567595.43
# 1  155966.02    245131.88  137811.38       NaN  538909.28         538909.28
# 2  212739.13    106088.18   16452.60       NaN  335279.91         335279.91
# 3   77916.00     56120.71  198306.90       NaN  332343.61         332343.61
# 4  134401.60      9737.00  182234.59       NaN  326373.19         326373.19
#
#    Year  Notes         Agency  Status
# ...

# %%
# Question 1
# Average BasePay
avg_basepay= data["BasePay"].mean()
print("The average Base Pay is", avg_basepay)

#Answer: The average Base Pay is 66325.44884050643
# Out:
# The average Base Pay is 66325.44884050643

# %%
# Question 2
# What are the TotalBenefits of JOSEPH DRISCOLL

p1= data.loc[data["EmployeeName"]== "JOSEPH DRISCOLL", "TotalPayBenefits"]
# Answer: 270324.91

# There is also a person named Joseph Driscoll, since Python is case sensitive, it treats them as two separate people
# Ensuring that the sum is reflected 
data.loc[data.EmployeeName.str.upper().str.contains("JOSEPH DRISCOLL"),"Benefits"].sum()
# Out:
# 42919.16

# %%
# Question 3- Highest paid person by name? 
pay = data["TotalPay"]
a=data["TotalPay"].max()
data.loc[data['TotalPay'] == a, 'EmployeeName'].iloc[0]
# Answer: 'NATHANIEL FORD'
# Out:
# 'NATHANIEL FORD'

# %%
# Question 4: What was the average (mean) BasePay of all employees per year? (2011-2014) ? 
newdata = data.groupby('Year')['BasePay'].mean()
newdata
# Out:
# Year
# 2011    63595.956517
# 2012    65436.406857
# 2013    69630.030216
# 2014    66564.421924
# Name: BasePay, dtype: float64

# %%
# Question 5:  How many Job Titles were represented by only one person in 2013  
(data[data.Year == 2013].JobTitle.value_counts()<=1).sum()
# Out:
# 202

# %%
# Question 6:How many people have the word Chief in their job title?
count1= data[data['JobTitle'].str.contains('CHIEF')]
count1.count()
#204 Counts
# Out:
#           Id        EmployeeName  \
# 4          5     PATRICK GARDNER
# 5          6      DAVID SULLIVAN
# 6          7           ALSON LEE
# 8          9      MICHAEL MORRIS
# 9         10  JOANNE HAYES-WHITE
# 10        11       ARTHUR KENNEY
# 14        15      DAVID FRANKLIN
# 18        19          MARTY ROSS
# 23        24       VICTOR WYRSCH
# 25        26        GREGORY SUHR
# 27        28      RAYMOND GUZMAN
# 28        29      DENISE SCHMITT
# 29        30       MONICA FIELDS
# 31        32         DAVID SHINN
# 34        35           JOSE VELO
# 39        40        BRENDAN WARD
# 40        41    MICHAEL THOMPSON
# 41        42       THOMAS ABBOTT
# 42        43     THOMAS SIRAGUSA
# 46        47    BRYAN RUBENSTEIN
# 48        49        JAMES DUDLEY
# 50        51     KIRK RICHARDSON
# 55        56       KEVIN CASHMAN
# 57        58        MARK KEARNEY
# 63        64       CHARLES CRANE
# 66        67       ROBERT POSTEL
# 68        69      THOMAS SHAWYER
# ...

# %%
# Question 7: Is there a correlation between length of the Job Title string and Salary

data["length"] = data.JobTitle.str.len()
data.head(2)
corr1= data["length"].corr(data["TotalPayBenefits"])
print("The correlation between the length of the title and salary is", corr1)
# Out:
# The correlation between the length of the title and salary is -0.0368784459326

# %%
# Question 8: Show a correlation heatmap of the data
# Since Notes and Status are empty columns, in order to ensure that the correlation matrix remains more interpretable, I have dropped those columns
data1.drop(data1.columns[[10, 11]], axis=1, inplace=True)
data1.head(2)
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-204-01873c8abc20> in <module>()
# ----> 1 data1.drop(data1.columns[[10, 11]], axis=1, inplace=True)
#       2 data1.head(2)
#       3 corr = data1.corr()
#       4
#       5 # plot the heatmap
#
# ~\Anaconda\lib\site-packages\pandas\core\indexes\base.py in __getitem__(self, key)
#    1698
#    1699         key = _values_from_object(key)
# -> 1700         result = getitem(key)
#    1701         if not is_scalar(result):
#    1702             return promote(result)
#
# IndexError: index 10 is out of bounds for axis 0 with size 10

# %%
corr = data1.corr()

# plot the heatmap
sns.heatmap(corr, 
        xticklabels=corr.columns,
        yticklabels=corr.columns)
plt.show()

# %%
# Question 9: Largest BasePay by Job 
job_group = data.groupby(['JobTitle'])['BasePay'].max()
job_group
# This gives the largest base pay for the variety of jobs that are present in the dataset
# For instance: There are 5 ACCOUNTANTS in the data set all with different base pays, but the highest basepay is 65392.01 as shown below
# Out:
# JobTitle
# ACCOUNT CLERK                                          60838.20
# ACCOUNTANT                                             65392.01
# ACCOUNTANT INTERN                                      58501.72
# ACPO,JuvP, Juv Prob (SFERS)                            62290.78
# ACUPUNCTURIST                                          66374.40
# ADMINISTRATIVE ANALYST                                 78587.89
# ADMINISTRATIVE ANALYST II                              75585.82
# ADMINISTRATIVE ANALYST III                             92847.00
# ADMINISTRATIVE ENGINEER                               136679.61
# ADMINISTRATIVE SERVICES MANAGER                        92002.00
# ADMINISTRATOR, SFGH MEDICAL CENTER                    245124.44
# AFFIRMATIVE ACTION SPECIALIST                          79696.00
# AGRICULTURAL INSPECTOR                                 57760.60
# AIRPORT ASSISTANT DEPUTY DIRECTOR, BUSINESS ADMINI      1927.50
# ...

# %%
# Question 10-Top 30 sectors (job titles) for SF salary 
top_30= data.sort_values('BasePay', ascending= False).head(30)['JobTitle']
top_30
# Out:
# 72925                            Chief of Police
# 110532                         Asst Med Examiner
# 72929               Dep Dir for Investments, Ret
# 72926                     Chief, Fire Department
# 72931                Executive Contract Employee
# 72932                                Dept Head V
# 110537                               Dept Head V
# 110538               Executive Contract Employee
# 110534                           Chief of Police
# 72933                 Gen Mgr, Public Trnsp Dept
# 36160                            Chief of Police
# 110535                    Chief, Fire Department
# 36162                     Chief, Fire Department
# 12                   EXECUTIVE CONTRACT EMPLOYEE
# 110541                Gen Mgr, Public Trnsp Dept
# 36165                 Gen Mgr, Public Trnsp Dept
# 36166                                Dept Head V
# 72935                                Dept Head V
# 72945                                      Mayor
# ...

# %%
# Question 11- Is BasePay a good predictor of TotalPay (in this case, just use correlation). 

corr_op= data['BasePay'].corr(data['TotalPay'])
print(" The correlation between the Base Pay and Total Pay is", corr_op)
# 0.95449364743
# This signifies that the total pay is highly and positively correlated to the base pay.  
#  It implies that if there is an increase in the base pay of persons salary, the total pay will increase as well

import matplotlib as mpl
import matplotlib.pyplot as plt
import seaborn as sns
sns.set(color_codes=True)
# Out:
#  The correlation between the Base Pay and Total Pay is 0.95449364743

# %%
plot1= sns.regplot(x="BasePay", y="TotalPay", data=data, line_kws={"color":"blue"});
plt.show()

# %%
## Bonus: Is there a strong correlation between vowel count in a name and average salary? Create a VowelCount column,
# and create a plot with these 2 variables. Can you show a correlation between these two variables? 
# Is it a strong one and what is it exactly? 

vowel =  "aeiou"
data["VowelCount"] = data.EmployeeName.str.lower().map(lambda x: sum(letter in vowel for letter in x))
corr_bonus =data["VowelCount"].corr(data["BasePay"])
print("The correlation between the number of vowels and the base pay is", corr_bonus)


# This indicates a very small correlation between the number of vowels and the salary.  They are also negatively correlated.
# It means that an increase in one quantity would lead to a decrease in the other quantity.
# Out:
# The correlation between the number of vowels and the base pay is -0.0499246197348

# %%
# Obserivations from the Data:
#The Dataset provided, is a very clean set of data.  Some of the columns that are not nescesary were removed while performing some
#analysis.  
# Due to time constraints, I was not able to take a deep-dive analysis. But from the employee data it is clear that the base pay 
# and benefits depended heavily on the Job Title of the person.

# %%
data.groupby(['Year'])['BasePay'].mean()
# Out:
# Year
# 2011    63595.956517
# 2012    65436.406857
# 2013    69630.030216
# 2014    66564.421924
# Name: BasePay, dtype: float64

# %%
data.groupby(['Year'])['TotalPayBenefits'].mean()
# Out:
# Year
# 2011     71744.103871
# 2012    100553.229232
# 2013    101440.519714
# 2014    100250.918884
# Name: TotalPayBenefits, dtype: float64

# %%
# We can see that as the years go by, the average salary does increase, but there was a drop in the average salaries from the year
# 2013 to 2014
# The TotalPayBenefits has had a consistent increase through the years
